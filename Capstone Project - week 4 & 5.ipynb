# %% [markdown]
# # Problem Statement
# ### Settling down in Toronto – Best place for an Indian based on number of Indian restaurants.
# Toronto is a large city and it is not easy for an Indian migrating to Toronto to determine the neighbourhood he should choose to settle down as it has a lot of diversity in demographics and various other factors. Let us take the number of Indian restaurants in the neighbourhood to choose which neighbourhood would be best for him to settle down.
#
# We visualise all neighbourhoods of Toronto and also compare the number of Indian restaurants as a parameter to choose the best place to settle down.

# %% [markdown]
# # Data
# ### For this project we need the following data:
# *Data source* : http://cocl.us/Geospatial_data
#
# *Description* : We will use this data for Toronto City which contains a list of Neighbourhoods along with their latitude and longitude.
#
# *Data source* : Fousquare API
#
# *Description* : Using Foursquare api, we will get all the venues in each neighbourhood and then we will filter these venues for only Indian restaurants.
# I will use the Kmeans

# %% [markdown]
# # Solution methodology
# From the above 2 data sources, I will be conducting clustering and neighborhood based analysis leveraging primarily Foursquare APIs and tools such as KNN to deliver recommendations options to the target user community primarily comprising of the Indian community.

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#     openssl:         1.0.2r-h7b6447c_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '1UKCODX3PQXELJTD4TVKCTIQAXGVDZ3JPZXGTTEPZGGRTXLY' # your Foursquare ID
CLIENT_SECRET = 'NQJ2ZKJXTR1BYOIDLE3HZK1RH3NQNSWLMZSBUB3IN5ASJQ3E' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1UKCODX3PQXELJTD4TVKCTIQAXGVDZ3JPZXGTTEPZGGRTXLY
# CLIENT_SECRET:NQJ2ZKJXTR1BYOIDLE3HZK1RH3NQNSWLMZSBUB3IN5ASJQ3E

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# 43.653963 -79.387207

# %%
search_query = '"Indian Restaurant"'
radius = 10000
LIMIT=100

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
print(url)
# Out:
# https://api.foursquare.com/v2/venues/search?client_id=1UKCODX3PQXELJTD4TVKCTIQAXGVDZ3JPZXGTTEPZGGRTXLY&client_secret=NQJ2ZKJXTR1BYOIDLE3HZK1RH3NQNSWLMZSBUB3IN5ASJQ3E&ll=43.653963,-79.387207&v=20180605&query="Indian Restaurant"&radius=10000&limit=100

# %%
# Get the json output for the search query "Indian"
result = requests.get(url).json()  
result
# Out:
# {'meta': {'code': 200, 'requestId': '5cf1047a351e3d1286ada83a'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4aef8854f964a5201cd921e3',
#     'location': {'address': '287 King St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St.',
#      'distance': 857,
#      'formattedAddress': ['287 King St. W (at John St.)',
#       'Toronto ON M5V 1J5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646462521503445,
#        'lng': -79.38964414801342}],
#      'lat': 43.646462521503445,
#      'lng': -79.38964414801342,
#      'postalCode': 'M5V 1J5',
#      'state': 'ON'},
#     'name': 'Aroma Fine Indian Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5165c333e4b07a7ad88d8a69',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 651,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65814977325445,
#        'lng': -79.38156263736568}],
#      'lat': 43.65814977325445,
#      'lng': -79.38156263736568},
#     'name': "Joe's Indian Restaurant",
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'primary': True,
#       'shortName': 'Fast Food'}],
#     'hasPerk': False,
#     'id': '53a07ba3498ee8946e98a7de',
#     'location': {'address': '552 Mt Pleasant',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1098,
#      'formattedAddress': ['552 Mt Pleasant', 'Toronto ON M4S 2M6', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64430171166487,
#        'lng': -79.39000236526671}],
#      'lat': 43.64430171166487,
#      'lng': -79.39000236526671,
#      'postalCode': 'M4S 2M6',
#      'state': 'ON'},
#     'name': 'Marigold Indian Bistro | Indian Restaurants in Toronto',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4ae4c793f964a5201b9e21e3',
#     'location': {'address': '1410 Gerrard St E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Ashdale Ave',
#      'distance': 5639,
#      'formattedAddress': ['1410 Gerrard St E (at Ashdale Ave)',
#       'Toronto ON M4L 1Z2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.672339,
#        'lng': -79.321941}],
#      'lat': 43.672339,
#      'lng': -79.321941,
#      'neighborhood': 'Little India, Toronto, ON',
#      'postalCode': 'M4L 1Z2',
#      'state': 'ON'},
#     'name': 'The Famous Indian Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '4dbb05154b222080d36d3d2f',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 6690,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.69659146611285,
#        'lng': -79.44578413818525}],
#      'lat': 43.69659146611285,
#      'lng': -79.44578413818525,
#      'state': 'ON'},
#     'name': 'Roti King West Indian Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '59e94c0260255e613b025e38',
#     'location': {'address': '15 Gervais Dr.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'across superstore',
#      'distance': 8646,
#      'formattedAddress': ['15 Gervais Dr. (across superstore)',
#       'Toronto ON M3C 1Y8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.722103,
#        'lng': -79.335655}],
#      'lat': 43.722103,
#      'lng': -79.335655,
#      'postalCode': 'M3C 1Y8',
#      'state': 'ON'},
#     'name': 'Patio Indian Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5c7da4b08ad62e0039395a08',
#     'location': {'address': '1646 Victoria Park Ave',
#      'cc': 'CA',
#      'city': 'North York',
#      'country': 'Canada',
#      'distance': 10788,
#      'formattedAddress': ['1646 Victoria Park Ave',
#       'North York ON M1R 1P7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7309565,
#        'lng': -79.3057989}],
#      'lat': 43.7309565,
#      'lng': -79.3057989,
#      'postalCode': 'M1R 1P7',
#      'state': 'ON'},
#     'name': 'Blue Water Curry & Roti West Indian Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52048f720e3',
#     'location': {'address': '110 Chestnut Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 145,
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'postalCode': 'M5G 1R3',
#      'state': 'ON'},
#     'name': 'Hemispheres Restaurant & Bistro',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4afd920ff964a520ad2822e3',
#     'location': {'address': '181 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'W of Chestnut St',
#      'distance': 136,
#      'formattedAddress': ['181 Dundas St W (W of Chestnut St)',
#       'Toronto ON M5G 1C7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65511996683289,
#        'lng': -79.3866447102921}],
#      'lat': 43.65511996683289,
#      'lng': -79.3866447102921,
#      'postalCode': 'M5G 1C7',
#      'state': 'ON'},
#     'name': 'Indian Biriyani House',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4b2a634af964a52020a824e3',
#     'location': {'address': '123 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btw Elizabeth & Bay',
#      'distance': 311,
#      'formattedAddress': ['123 Dundas St W (btw Elizabeth & Bay)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564910619165,
#        'lng': -79.38411937886697}],
#      'lat': 43.65564910619165,
#      'lng': -79.38411937886697,
#      'state': 'ON'},
#     'name': 'Indian Flavour',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a52006f620e3',
#     'location': {'address': '37 King Street East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Le Meridien King Edward Hotel',
#      'distance': 1011,
#      'formattedAddress': ['37 King Street East (at Le Meridien King Edward Hotel)',
#       'Toronto ON M5C 1E9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64929834396347,
#        'lng': -79.37643067251867}],
#      'lat': 43.64929834396347,
#      'lng': -79.37643067251867,
#      'postalCode': 'M5C 1E9',
#      'state': 'ON'},
#     'name': "Victoria's Restaurant",
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '498556908'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b2027b5f964a520f82d24e3',
#     'location': {'address': '195 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at University Ave',
#      'distance': 107,
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'postalCode': 'M5G 1C7',
#      'state': 'ON'},
#     'name': 'Hong Shing Chinese Restaurant',
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '60327598'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4fea497c121d2480d3579412',
#     'location': {'address': '120 Adelaide Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bay Street',
#      'distance': 683,
#      'formattedAddress': ['120 Adelaide Street West (at Bay Street)',
#       'Toronto ON M5H 3V1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650050280518336,
#        'lng': -79.38066244125366}],
#      'lat': 43.650050280518336,
#      'lng': -79.38066244125366,
#      'postalCode': 'M5H 3V1',
#      'state': 'ON'},
#     'name': 'Indian Biriyani House',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'primary': True,
#       'shortName': 'School'}],
#     'hasPerk': False,
#     'id': '4cc5b3babe40a35d7c01864c',
#     'location': {'address': '285 Indian Road Cres',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 5907,
#      'formattedAddress': ['285 Indian Road Cres',
#       'Toronto ON M6P 2G8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66249140470172,
#        'lng': -79.4596075614885}],
#      'lat': 43.66249140470172,
#      'lng': -79.4596075614885,
#      'postalCode': 'M6P 2G8',
#      'state': 'ON'},
#     'name': 'Indian Road Crescent Public School',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5c33c7cd8194fc002c66f72e',
#     'location': {'address': '261 Spadina Avenue. Upper level',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 845,
#      'formattedAddress': ['261 Spadina Avenue. Upper level',
#       'Toronto ON M5T 2E3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652487830335545,
#        'lng': -79.39750134944916}],
#      'lat': 43.652487830335545,
#      'lng': -79.39750134944916,
#      'postalCode': 'M5T 2E3',
#      'state': 'ON'},
#     'name': 'Green Tea Restaurant Downtown',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b223f5af964a520ba4424e3',
#     'location': {'address': '225 Frnt St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1039,
#      'formattedAddress': ['225 Frnt St W', 'Toronto ON M5V 2X3', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644749195919346,
#        'lng': -79.38511295085902}],
#      'lat': 43.644749195919346,
#      'lng': -79.38511295085902,
#      'neighborhood': 'Entertainment District',
#      'postalCode': 'M5V 2X3',
#      'state': 'ON'},
#     'name': 'Azure Restaurant & Bar',
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '136175835'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'primary': True,
#       'shortName': 'Vietnamese'}],
#     'hasPerk': False,
#     'id': '4c476d6719fde21e32410876',
#     'location': {'address': '179 Dundas St. W.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Chestnut',
#      'distance': 140,
#      'formattedAddress': ['179 Dundas St. W. (at Chestnut)',
#       'Toronto ON M5G',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65506808,
#        'lng': -79.386375}],
#      'lat': 43.65506808,
#      'lng': -79.386375,
#      'postalCode': 'M5G',
#      'state': 'ON'},
#     'name': 'Cali Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4ada6d8df964a520832221e3',
#     'location': {'address': '72 Ossington Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen St. W',
#      'distance': 2755,
#      'formattedAddress': ['72 Ossington Ave. (Queen St. W)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64585979013257,
#        'lng': -79.41953208988866}],
#      'lat': 43.64585979013257,
#      'lng': -79.41953208988866,
#      'state': 'ON'},
#     'name': 'Union Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4d06c1ccc2e53704428cc567',
#     'location': {'address': '476 Dundas St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Huron',
#      'distance': 767,
#      'formattedAddress': ['476 Dundas St. (Huron)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6531846832903,
#        'lng': -79.3966766276528}],
#      'lat': 43.6531846832903,
#      'lng': -79.3966766276528,
#      'state': 'ON'},
#     'name': 'North-East Chinese Restaurant 華北美食',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520dff520e3',
#     'location': {'address': '301 Front St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '301 Front St. W',
#      'distance': 1271,
#      'formattedAddress': ['301 Front St W (301 Front St. W)',
#       'Toronto ON M5V 2T6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642537317144566,
#        'lng': -79.38704201569328}],
#      'lat': 43.642537317144566,
#      'lng': -79.38704201569328,
#      'postalCode': 'M5V 2T6',
#      'state': 'ON'},
#     'name': '360 Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '50ca02c0245f2d4aa8c2b313',
#     'location': {'address': '145 Richmond Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Hilton Toronto',
#      'distance': 458,
#      'formattedAddress': ['145 Richmond Street West (Hilton Toronto)',
#       'Toronto ON M5H 2L2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650009987649646,
#        'lng': -79.38560774268629}],
#      'lat': 43.650009987649646,
#      'lng': -79.38560774268629,
#      'postalCode': 'M5H 2L2',
#      'state': 'ON'},
#     'name': 'Tundra Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'primary': True,
#       'shortName': 'Food Truck'}],
#     'hasPerk': False,
#     'id': '596f9dea1fa7632be2eacab9',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 354,
#      'formattedAddress': ['Toronto ON M5G 2N2', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65698561897954,
#        'lng': -79.38584032854251}],
#      'lat': 43.65698561897954,
#      'lng': -79.38584032854251,
#      'postalCode': 'M5G 2N2',
#      'state': 'ON'},
#     'name': "Mami's Indian Cuisine",
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4c69740b8d22c9284d42b745',
#     'location': {'address': '56 Centre Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 96,
#      'formattedAddress': ['56 Centre Ave.', 'Toronto ON M5G 1R5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65483285234745,
#        'lng': -79.38720597193928}],
#      'lat': 43.65483285234745,
#      'lng': -79.38720597193928,
#      'postalCode': 'M5G 1R5',
#      'state': 'ON'},
#     'name': 'Wah Too Seafood Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '50b79b94e4b0a577af25a83f',
#     'location': {'address': '256 Queens Quay W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Rees St & Lower Simcoe S',
#      'distance': 1665,
#      'formattedAddress': ['256 Queens Quay W (btwn Rees St & Lower Simcoe S)',
#       'Toronto ON M5J 1B5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63906038875002,
#        'lng': -79.38542224544638}],
#      'lat': 43.63906038875002,
#      'lng': -79.38542224544638,
#      'postalCode': 'M5J 1B5',
#      'state': 'ON'},
#     'name': 'Indian Roti House',
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '43722371'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'primary': True,
#       'shortName': 'Thai'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52018f720e3',
#     'location': {'address': '338 Jarvis St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'north of Carlton Street',
#      'distance': 1284,
#      'formattedAddress': ['338 Jarvis St. (north of Carlton Street)',
#       'Toronto ON M4Y 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66277006654972,
#        'lng': -79.37689434011018}],
#      'lat': 43.66277006654972,
#      'lng': -79.37689434011018,
#      'postalCode': 'M4Y 2G6',
#      'state': 'ON'},
#     'name': 'Cottage Restaurant & Lounge',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4b072e9df964a52009f922e3',
#     'location': {'address': '280 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Dundas St. W.',
#      'distance': 892,
#      'formattedAddress': ['280 Spadina Ave. (at Dundas St. W.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65278331265585,
#        'lng': -79.39817372355205}],
#      'lat': 43.65278331265585,
#      'lng': -79.39817372355205,
#      'state': 'ON'},
#     'name': 'Sky Dragon Chinese Restaurant 龍翔酒樓',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4d137f8c7a8ba1433cb3d169',
#     'location': {'address': '1 Adelaide St. E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Yonge St',
#      'distance': 855,
#      'formattedAddress': ['1 Adelaide St. E (at Yonge St)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64986899674456,
#        'lng': -79.37821832718096}],
#      'lat': 43.64986899674456,
#      'lng': -79.37821832718096,
#      'state': 'ON'},
#     'name': 'Touch - Indian Cuisine',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4e122e6cb0fbfef99b985de1',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 553,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655946,
#        'lng': -79.393504}],
#      'lat': 43.655946,
#      'lng': -79.393504,
#      'state': 'ON'},
#     'name': 'Jodpore Club Indian Cuisine',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '5b1c3098f96b2c002c5eb0c5',
#     'location': {'address': '405 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'College St',
#      'distance': 1019,
#      'formattedAddress': ['405 Spadina Ave (College St)',
#       'Toronto ON M5T 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656794,
#        'lng': -79.399251}],
#      'lat': 43.656794,
#      'lng': -79.399251,
#      'postalCode': 'M5T 2G6',
#      'state': 'ON'},
#     'name': "Tasty's Caribbean Restaurant & Catering",
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a5200bf720e3',
#     'location': {'address': '346-348 Spadina Avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 960,
#      'formattedAddress': ['346-348 Spadina Avenue',
#       'Toronto ON M5T 2G2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654219,
#        'lng': -79.399125}],
#      'lat': 43.654219,
#      'lng': -79.399125,
#      'postalCode': 'M5T 2G2',
#      'state': 'ON'},
#     'name': 'Bright Pearl Seafood Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05df964a5203ff620e3',
#     'location': {'address': '30 Mercer Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St',
#      'distance': 979,
#      'formattedAddress': ['30 Mercer Street (at John St)',
#       'Toronto ON M5V 1H3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64563436248102,
#        'lng': -79.39112538566908}],
#      'lat': 43.64563436248102,
#      'lng': -79.39112538566908,
#      'postalCode': 'M5V 1H3',
#      'state': 'ON'},
#     'name': 'Victor Restaurant & Bar',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b4d3b51f964a520e4ce26e3',
#     'location': {'address': '90 Bloor St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Yonge St.',
#      'distance': 1858,
#      'formattedAddress': ['90 Bloor St. (Yonge St.)',
#       'Toronto ON M4W 1A7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67057375344845,
#        'lng': -79.38485582052517}],
#      'lat': 43.67057375344845,
#      'lng': -79.38485582052517,
#      'postalCode': 'M4W 1A7',
#      'state': 'ON'},
#     'name': 'Matisse Restaurant And Bar',
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '83923512'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b82c671f964a52016e430e3',
#     'location': {'address': '250 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 211,
#      'formattedAddress': ['250 Dundas St W', 'Toronto ON M5T 2Z5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654588,
#        'lng': -79.389692}],
#      'lat': 43.654588,
#      'lng': -79.389692,
#      'postalCode': 'M5T 2Z5',
#      'state': 'ON'},
#     'name': 'Anoush Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5834c90e110d032f3217f899',
#     'location': {'address': '67 Richmond Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Richmond and Bay Street',
#      'distance': 537,
#      'formattedAddress': ['67 Richmond Street West (Richmond and Bay Street)',
#       'Toronto ON M5H 1Z5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651090520885205,
#        'lng': -79.38184261322021}],
#      'lat': 43.651090520885205,
#      'lng': -79.38184261322021,
#      'postalCode': 'M5H 1Z5',
#      'state': 'ON'},
#     'name': 'Maezo Restaurant & Bar',
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '369067217'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4bd47e6fcfa7b7139f2924da',
#     'location': {'address': '389 Church St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Carlton St.',
#      'distance': 1052,
#      'formattedAddress': ['389 Church St. (at Carlton St.)',
#       'Toronto ON M5B',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661500159065305,
#        'lng': -79.3793192447337}],
#      'lat': 43.661500159065305,
#      'lng': -79.3793192447337,
#      'postalCode': 'M5B',
#      'state': 'ON'},
#     'name': 'Studio Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5a8b24b2018cbb6c4ca70dae',
#     'location': {'address': 'Yonge And Queen',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 607,
#      'formattedAddress': ['Yonge And Queen', 'Toronto ON M5G 2H6', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65341542752959,
#        'lng': -79.37969842137554}],
#      'lat': 43.65341542752959,
#      'lng': -79.37969842137554,
#      'postalCode': 'M5G 2H6',
#      'state': 'ON'},
#     'name': 'Hendricks Restaurant & Bar',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'primary': True,
#       'shortName': 'Japanese'}],
#     'hasPerk': False,
#     'id': '4c12b8ba82a3c9b6083ffaf8',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 541,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658555,
#        'lng': -79.384992}],
#      'lat': 43.658555,
#      'lng': -79.384992,
#      'state': 'ON'},
#     'name': 'Mt. Fuji Japanese Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '562922be498e2c6aad0e6091',
#     'location': {'address': '25 Lower Simcoe St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Grand Trunk Cresc',
#      'distance': 1411,
#      'formattedAddress': ['25 Lower Simcoe St (Grand Trunk Cresc)',
#       'Toronto ON M5J 3A1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64157991761808,
#        'lng': -79.38345644030795}],
#      'lat': 43.64157991761808,
#      'lng': -79.38345644030795,
#      'postalCode': 'M5J 3A1',
#      'state': 'ON'},
#     'name': 'Evviva Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5c7969857dc9e1002c4e3819',
#     'location': {'address': '51 Colborne Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1132,
#      'formattedAddress': ['51 Colborne Street',
#       'Toronto ON M5E 0B7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649153,
#        'lng': -79.374814}],
#      'lat': 43.649153,
#      'lng': -79.374814,
#      'postalCode': 'M5E 0B7',
#      'state': 'ON'},
#     'name': 'Chadani Indian Cuisine',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '52a7ae41498eed3af4d0a3fa',
#     'location': {'address': '126 Elizabeth St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St.',
#      'distance': 210,
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'state': 'ON'},
#     'name': 'Yueh Tung Chinese Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5c636fa1492814002c0cb117',
#     'location': {'address': '100 Yonge St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Yonge and King',
#      'distance': 849,
#      'formattedAddress': ['100 Yonge St (Yonge and King)',
#       'Toronto ON M5C 2W1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64982,
#        'lng': -79.37835}],
#      'lat': 43.64982,
#      'lng': -79.37835,
#      'neighborhood': 'Financial District',
#      'postalCode': 'M5C 2W1',
#      'state': 'ON'},
#     'name': 'Cru Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '547fcf8d498eea18a9c440c5',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 920,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646989,
#        'lng': -79.393345}],
#      'lat': 43.646989,
#      'lng': -79.393345},
#     'name': 'Amaya Fine Indian Cuisine',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5b189725d552c7002c0d64c0',
#     'location': {'address': '199 Bay St 6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 889,
#      'formattedAddress': ['199 Bay St 6', 'Toronto ON M5L 1E2', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648025841,
#        'lng': -79.379818887}],
#      'lat': 43.648025841,
#      'lng': -79.379818887,
#      'postalCode': 'M5L 1E2',
#      'state': 'ON'},
#     'name': "Ram's Indian kitchen",
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4cb4bf4064998cfaa7f608a2',
#     'location': {'address': '370 King St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Peter St.',
#      'distance': 924,
#      'formattedAddress': ['370 King St. W (at Peter St.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64624476965642,
#        'lng': -79.39145906970307}],
#      'lat': 43.64624476965642,
#      'lng': -79.39145906970307,
#      'state': 'ON'},
#     'name': 'Mix Bistro Restaurant and Bar at the Hyatt Regency',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4ad7929cf964a520500c21e3',
#     'location': {'address': '249 Victoria Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'distance': 671,
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'postalCode': 'M5B 1T8',
#      'state': 'ON'},
#     'name': 'The Senator Restaurant',
#     'referralId': 'v-1559299194',
#     'venuePage': {'id': '55585058'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '59c04747123a197d7984042b',
#     'location': {'address': '309 King Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 907,
#      'formattedAddress': ['309 King Street West', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646095,
#        'lng': -79.390144}],
#      'lat': 43.646095,
#      'lng': -79.390144,
#      'state': 'ON'},
#     'name': 'Dhaba Indian Cuisine',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4c47d78c1ddec92817ca9e32',
#     'location': {'address': '566 Queen St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1507,
#      'formattedAddress': ['566 Queen St W', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647289322295066,
#        'lng': -79.40349333397708}],
#      'lat': 43.647289322295066,
#      'lng': -79.40349333397708,
#      'state': 'ON'},
#     'name': "Micheal's Restaurant and Deli",
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '51e0a7c492093977ebd16779',
#     'location': {'address': '630 Bloor St. West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 2485,
#      'formattedAddress': ['630 Bloor St. West',
#       'Toronto ON M6G 1K7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.664442,
#        'lng': -79.414456}],
#      'lat': 43.664442,
#      'lng': -79.414456,
#      'postalCode': 'M6G 1K7',
#      'state': 'ON'},
#     'name': '630 Maroli Indian Kerala Restaurant',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4c7d2f9b10916dcbb99a2896',
#     'location': {'address': '10 Kings College Rd.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in Sandford Fleming',
#      'distance': 908,
#      'formattedAddress': ['10 Kings College Rd. (in Sandford Fleming)',
#       'Toronto ON M5S 3G4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65980608863362,
#        'lng': -79.39508379136744}],
#      'lat': 43.65980608863362,
#      'lng': -79.39508379136744,
#      'postalCode': 'M5S 3G4',
#      'state': 'ON'},
#     'name': 'Veda Healthy Indian Takeout',
#     'referralId': 'v-1559299194'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a05',
#       'name': 'English Restaurant',
#       'pluralName': 'English Restaurants',
#       'primary': True,
#       'shortName': 'English'}],
#     'hasPerk': False,
#     'id': '5c0ee730e55d8b002cb81e10',
#     'location': {'address': '287 Richmond St West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen and Peter',
#      'distance': 740,
#      'formattedAddress': ['287 Richmond St West (Queen and Peter)',
#       'Toronto ON M5V 1X1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648594,
#        'lng': -79.39263}],
#      'lat': 43.648594,
#      'lng': -79.39263,
#      'postalCode': 'M5V 1X1',
#      'state': 'ON'},
#     'name': 'Queen Anne Restaurant',
#     'referralId': 'v-1559299194'}]}}

# %%
# assigning relevant part of JSON to venues
venues = result['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'pluralName': 'Indian Restaurants', 'id': '4...    False
# 1  [{'pluralName': 'Indian Restaurants', 'id': '4...    False
# 2  [{'pluralName': 'Fast Food Restaurants', 'id':...    False
# 3  [{'pluralName': 'American Restaurants', 'id': ...    False
# 4  [{'pluralName': 'Indian Restaurants', 'id': '4...    False
#
#                          id     location.address location.cc location.city  \
# 0  4aef8854f964a5201cd921e3       287 King St. W          CA       Toronto
# 1  5165c333e4b07a7ad88d8a69                  NaN          CA           NaN
# 2  53a07ba3498ee8946e98a7de      552 Mt Pleasant          CA       Toronto
# 3  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 4  4afd920ff964a520ad2822e3      181 Dundas St W          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at John St.                857
# 1           Canada                  NaN                651
# 2           Canada                  NaN               1098
# 3           Canada                  NaN                145
# 4           Canada     W of Chestnut St                136
#
#                            location.formattedAddress  \
# 0  [287 King St. W (at John St.), Toronto ON M5V ...
# 1                                           [Canada]
# 2      [552 Mt Pleasant, Toronto ON M4S 2M6, Canada]
# 3  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 4  [181 Dundas St W (W of Chestnut St), Toronto O...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 43.646462521503445, 'label': 'display...     43.646463
# 1  [{'lat': 43.65814977325445, 'label': 'display'...     43.658150
# 2  [{'lat': 43.64430171166487, 'label': 'display'...     43.644302
# 3  [{'lat': 43.65488413420439, 'label': 'display'...     43.654884
# 4  [{'lat': 43.65511996683289, 'label': 'display'...     43.655120
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.389644                   NaN             M5V 1J5             ON
# 1    -79.381563                   NaN                 NaN            NaN
# 2    -79.390002                   NaN             M4S 2M6             ON
# 3    -79.385931                   NaN             M5G 1R3             ON
# 4    -79.386645                   NaN             M5G 1C7             ON
#
#                                                 name    referralId  \
# 0                       Aroma Fine Indian Restaurant  v-1559298365
# 1                            Joe's Indian Restaurant  v-1559298365
# 2  Marigold Indian Bistro | Indian Restaurants in...  v-1559298365
# 3                    Hemispheres Restaurant & Bistro  v-1559298365
# 4                              Indian Biriyani House  v-1559298365
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Obtaining only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                        Aroma Fine Indian Restaurant
# 1                             Joe's Indian Restaurant
# 2   Marigold Indian Bistro | Indian Restaurants in...
# 3                     Hemispheres Restaurant & Bistro
# 4                               Indian Biriyani House
# 5                                      Indian Flavour
# 6                               Victoria's Restaurant
# 7                       Hong Shing Chinese Restaurant
# 8                               Indian Biriyani House
# 9                  Indian Road Crescent Public School
# 10                      Green Tea Restaurant Downtown
# 11                             Azure Restaurant & Bar
# 12                                  Indian Roti House
# 13                                    Cali Restaurant
# 14                                   Union Restaurant
# 15                 North-East Chinese Restaurant 華北美食
# 16                                     360 Restaurant
# 17                                  Tundra Restaurant
# 18                              Mami's Indian Cuisine
# 19                         Wah Too Seafood Restaurant
# 20                                  Indian Roti House
# 21                        Cottage Restaurant & Lounge
# 22                 Sky Dragon Chinese Restaurant 龍翔酒樓
# 23                             Touch - Indian Cuisine
# 24                        Jodpore Club Indian Cuisine
# 25            Tasty's Caribbean Restaurant & Catering
# 26                    Bright Pearl Seafood Restaurant
# 27                            Victor Restaurant & Bar
# 28                         Matisse Restaurant And Bar
# 29                                  Anoush Restaurant
# 30                             Maezo Restaurant & Bar
# 31                                  Studio Restaurant
# 32                         Hendricks Restaurant & Bar
# 33                       Mt. Fuji Japanese Restaurant
# 34                                  Evviva Restaurant
# 35                             Chadani Indian Cuisine
# 36                       Yueh Tung Chinese Restaurant
# 37                                     Cru Restaurant
# 38                          Amaya Fine Indian Cuisine
# 39                               Ram's Indian kitchen
# 40  Mix Bistro Restaurant and Bar at the Hyatt Reg...
# 41                             The Senator Restaurant
# 42                               Dhaba Indian Cuisine
# 43                            Osgoode Hall Restaurant
# 44                      Micheal's Restaurant and Deli
# 45                630 Maroli Indian Kerala Restaurant
# 46                        Veda Healthy Indian Takeout
# 47                              Queen Anne Restaurant
# 48                          Kim Vietnamese Restaurant
# 49                            The Lakeview Restaurant
#
#                  categories                          address  cc     city  \
# 0         Indian Restaurant                   287 King St. W  CA  Toronto
# 1         Indian Restaurant                              NaN  CA      NaN
# 2      Fast Food Restaurant                  552 Mt Pleasant  CA  Toronto
# 3       American Restaurant              110 Chestnut Street  CA  Toronto
# 4         Indian Restaurant                  181 Dundas St W  CA  Toronto
# 5         Indian Restaurant                  123 Dundas St W  CA  Toronto
# 6                Restaurant              37 King Street East  CA  Toronto
# 7        Chinese Restaurant                  195 Dundas St W  CA  Toronto
# 8         Indian Restaurant         120 Adelaide Street West  CA  Toronto
# 9                    School             285 Indian Road Cres  CA  Toronto
# 10               Restaurant  261 Spadina Avenue. Upper level  CA  Toronto
# 11               Restaurant                    225 Frnt St W  CA  Toronto
# 12        Indian Restaurant                              NaN  CA  Toronto
# 13    Vietnamese Restaurant                179 Dundas St. W.  CA  Toronto
# 14  New American Restaurant                72 Ossington Ave.  CA  Toronto
# 15       Chinese Restaurant                   476 Dundas St.  CA  Toronto
# 16                 Wine Bar                   301 Front St W  CA  Toronto
# 17               Restaurant         145 Richmond Street West  CA  Toronto
# 18               Food Truck                              NaN  CA  Toronto
# 19       Chinese Restaurant                   56 Centre Ave.  CA  Toronto
# 20        Indian Restaurant                256 Queens Quay W  CA  Toronto
# 21          Thai Restaurant                   338 Jarvis St.  CA  Toronto
# 22       Dim Sum Restaurant                 280 Spadina Ave.  CA  Toronto
# 23        Indian Restaurant                 1 Adelaide St. E  CA  Toronto
# 24        Indian Restaurant                              NaN  CA  Toronto
# 25     Caribbean Restaurant                  405 Spadina Ave  CA  Toronto
# 26       Chinese Restaurant           346-348 Spadina Avenue  CA  Toronto
# 27                      Bar                 30 Mercer Street  CA  Toronto
# 28               Restaurant                     90 Bloor St.  CA  Toronto
# 29               Restaurant                  250 Dundas St W  CA  Toronto
# 30        Indian Restaurant          67 Richmond Street West  CA  Toronto
# 31           Breakfast Spot                   389 Church St.  CA  Toronto
# 32               Restaurant                  Yonge And Queen  CA  Toronto
# 33      Japanese Restaurant                              NaN  CA  Toronto
# 34            Deli / Bodega               25 Lower Simcoe St  CA  Toronto
# 35        Indian Restaurant               51 Colborne Street  CA  Toronto
# 36       Chinese Restaurant                126 Elizabeth St.  CA  Toronto
# 37               Restaurant                     100 Yonge St  CA  Toronto
# 38        Indian Restaurant                              NaN  CA      NaN
# 39        Indian Restaurant                     199 Bay St 6  CA  Toronto
# 40               Restaurant                   370 King St. W  CA  Toronto
# 41                    Diner              249 Victoria Street  CA  Toronto
# 42        Indian Restaurant             309 King Street West  CA  Toronto
# 43  New American Restaurant                   130 Queen St W  CA      NaN
# 44                      Bar                   566 Queen St W  CA  Toronto
# 45               Restaurant               630 Bloor St. West  CA  Toronto
# 46        Indian Restaurant             10 Kings College Rd.  CA  Toronto
# 47       English Restaurant             287 Richmond St West  CA  Toronto
# 48    Vietnamese Restaurant                  546 Dundas St W  CA  Toronto
# 49                    Diner                1132 Dundas St. W  CA  Toronto
#
#    country                       crossStreet  distance  \
# 0   Canada                       at John St.       857
# 1   Canada                               NaN       651
# 2   Canada                               NaN      1098
# 3   Canada                               NaN       145
# 4   Canada                  W of Chestnut St       136
# 5   Canada               btw Elizabeth & Bay       311
# 6   Canada  at Le Meridien King Edward Hotel      1011
# 7   Canada                 at University Ave       107
# 8   Canada                     at Bay Street       683
# 9   Canada                               NaN      5907
# 10  Canada                               NaN       845
# 11  Canada                               NaN      1039
# 12  Canada                               NaN      1280
# 13  Canada                       at Chestnut       140
# 14  Canada                       Queen St. W      2755
# 15  Canada                             Huron       767
# 16  Canada                   301 Front St. W      1271
# 17  Canada                    Hilton Toronto       458
# 18  Canada                               NaN       354
# 19  Canada                               NaN        96
# 20  Canada     btwn Rees St & Lower Simcoe S      1665
# 21  Canada           north of Carlton Street      1284
# 22  Canada                  at Dundas St. W.       892
# 23  Canada                       at Yonge St       855
# 24  Canada                               NaN       553
# 25  Canada                        College St      1019
# 26  Canada                               NaN       960
# 27  Canada                        at John St       979
# 28  Canada                         Yonge St.      1858
# 29  Canada                               NaN       211
# 30  Canada           Richmond and Bay Street       537
# 31  Canada                    at Carlton St.      1052
# 32  Canada                               NaN       607
# 33  Canada                               NaN       541
# 34  Canada                 Grand Trunk Cresc      1411
# 35  Canada                               NaN      1132
# 36  Canada                        Dundas St.       210
# 37  Canada                    Yonge and King       849
# 38  Canada                               NaN       920
# 39  Canada                               NaN       889
# 40  Canada                      at Peter St.       924
# 41  Canada    btwn Dundas St E and Shuter St       671
# 42  Canada                               NaN       907
# 43  Canada                    University Ave       281
# 44  Canada                               NaN      1507
# 45  Canada                               NaN      2485
# 46  Canada               in Sandford Fleming       908
# 47  Canada                   Queen and Peter       740
# 48  Canada                               NaN       989
# 49  Canada                 at Ossington Ave.      2719
#
#                                      formattedAddress  \
# 0   [287 King St. W (at John St.), Toronto ON M5V ...
# 1                                            [Canada]
# 2       [552 Mt Pleasant, Toronto ON M4S 2M6, Canada]
# 3   [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 4   [181 Dundas St W (W of Chestnut St), Toronto O...
# 5   [123 Dundas St W (btw Elizabeth & Bay), Toront...
# 6   [37 King Street East (at Le Meridien King Edwa...
# 7   [195 Dundas St W (at University Ave), Toronto ...
# 8   [120 Adelaide Street West (at Bay Street), Tor...
# 9   [285 Indian Road Cres, Toronto ON M6P 2G8, Can...
# 10  [261 Spadina Avenue. Upper level, Toronto ON M...
# 11        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 12                               [Toronto ON, Canada]
# 13  [179 Dundas St. W. (at Chestnut), Toronto ON M...
# 14  [72 Ossington Ave. (Queen St. W), Toronto ON, ...
# 15       [476 Dundas St. (Huron), Toronto ON, Canada]
# 16  [301 Front St W (301 Front St. W), Toronto ON ...
# 17  [145 Richmond Street West (Hilton Toronto), To...
# 18                       [Toronto ON M5G 2N2, Canada]
# 19       [56 Centre Ave., Toronto ON M5G 1R5, Canada]
# 20  [256 Queens Quay W (btwn Rees St & Lower Simco...
# 21  [338 Jarvis St. (north of Carlton Street), Tor...
# 22  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 23  [1 Adelaide St. E (at Yonge St), Toronto ON, C...
# 24                               [Toronto ON, Canada]
# 25  [405 Spadina Ave (College St), Toronto ON M5T ...
# 26  [346-348 Spadina Avenue, Toronto ON M5T 2G2, C...
# 27  [30 Mercer Street (at John St), Toronto ON M5V...
# 28  [90 Bloor St. (Yonge St.), Toronto ON M4W 1A7,...
# 29      [250 Dundas St W, Toronto ON M5T 2Z5, Canada]
# 30  [67 Richmond Street West (Richmond and Bay Str...
# 31  [389 Church St. (at Carlton St.), Toronto ON M...
# 32      [Yonge And Queen, Toronto ON M5G 2H6, Canada]
# 33                               [Toronto ON, Canada]
# 34  [25 Lower Simcoe St (Grand Trunk Cresc), Toron...
# 35   [51 Colborne Street, Toronto ON M5E 0B7, Canada]
# 36  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 37  [100 Yonge St (Yonge and King), Toronto ON M5C...
# 38                                           [Canada]
# 39         [199 Bay St 6, Toronto ON M5L 1E2, Canada]
# 40  [370 King St. W (at Peter St.), Toronto ON, Ca...
# 41  [249 Victoria Street (btwn Dundas St E and Shu...
# 42         [309 King Street West, Toronto ON, Canada]
# 43  [130 Queen St W (University Ave), M5H 2N6, Can...
# 44               [566 Queen St W, Toronto ON, Canada]
# 45   [630 Bloor St. West, Toronto ON M6G 1K7, Canada]
# 46  [10 Kings College Rd. (in Sandford Fleming), T...
# 47  [287 Richmond St West (Queen and Peter), Toron...
# 48      [546 Dundas St W, Toronto ON M5T 1H3, Canada]
# 49  [1132 Dundas St. W (at Ossington Ave.), Toront...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lat': 43.646462521503445, 'label': 'display...  43.646463 -79.389644
# 1   [{'lat': 43.65814977325445, 'label': 'display'...  43.658150 -79.381563
# 2   [{'lat': 43.64430171166487, 'label': 'display'...  43.644302 -79.390002
# 3   [{'lat': 43.65488413420439, 'label': 'display'...  43.654884 -79.385931
# 4   [{'lat': 43.65511996683289, 'label': 'display'...  43.655120 -79.386645
# 5   [{'lat': 43.65564910619165, 'label': 'display'...  43.655649 -79.384119
# 6   [{'lat': 43.64929834396347, 'label': 'display'...  43.649298 -79.376431
# 7   [{'lat': 43.65492521335936, 'label': 'display'...  43.654925 -79.387089
# 8   [{'lat': 43.650050280518336, 'label': 'display...  43.650050 -79.380662
# 9   [{'lat': 43.66249140470172, 'label': 'display'...  43.662491 -79.459608
# 10  [{'lat': 43.652487830335545, 'label': 'display...  43.652488 -79.397501
# 11  [{'lat': 43.644749195919346, 'label': 'display...  43.644749 -79.385113
# 12  [{'lat': 43.66438249736424, 'label': 'display'...  43.664382 -79.380468
# 13  [{'lat': 43.65506808, 'label': 'display', 'lng...  43.655068 -79.386375
# 14  [{'lat': 43.64585979013257, 'label': 'display'...  43.645860 -79.419532
# 15  [{'lat': 43.6531846832903, 'label': 'display',...  43.653185 -79.396677
# 16  [{'lat': 43.642537317144566, 'label': 'display...  43.642537 -79.387042
# 17  [{'lat': 43.650009987649646, 'label': 'display...  43.650010 -79.385608
# 18  [{'lat': 43.65698561897954, 'label': 'display'...  43.656986 -79.385840
# 19  [{'lat': 43.65483285234745, 'label': 'display'...  43.654833 -79.387206
# 20  [{'lat': 43.63906038875002, 'label': 'display'...  43.639060 -79.385422
# 21  [{'lat': 43.66277006654972, 'label': 'display'...  43.662770 -79.376894
# 22  [{'lat': 43.65278331265585, 'label': 'display'...  43.652783 -79.398174
# 23  [{'lat': 43.64986899674456, 'label': 'display'...  43.649869 -79.378218
# 24  [{'lat': 43.655946, 'label': 'display', 'lng':...  43.655946 -79.393504
# 25  [{'lat': 43.656794, 'label': 'display', 'lng':...  43.656794 -79.399251
# 26  [{'lat': 43.654219, 'label': 'display', 'lng':...  43.654219 -79.399125
# 27  [{'lat': 43.64563436248102, 'label': 'display'...  43.645634 -79.391125
# 28  [{'lat': 43.67057375344845, 'label': 'display'...  43.670574 -79.384856
# 29  [{'lat': 43.654588, 'label': 'display', 'lng':...  43.654588 -79.389692
# 30  [{'lat': 43.651090520885205, 'label': 'display...  43.651091 -79.381843
# 31  [{'lat': 43.661500159065305, 'label': 'display...  43.661500 -79.379319
# 32  [{'lat': 43.65341542752959, 'label': 'display'...  43.653415 -79.379698
# 33  [{'lat': 43.658555, 'label': 'display', 'lng':...  43.658555 -79.384992
# 34  [{'lat': 43.64157991761808, 'label': 'display'...  43.641580 -79.383456
# 35  [{'lat': 43.649153, 'label': 'display', 'lng':...  43.649153 -79.374814
# 36  [{'lat': 43.655281263429195, 'label': 'display...  43.655281 -79.385337
# 37  [{'lat': 43.64982, 'label': 'display', 'lng': ...  43.649820 -79.378350
# 38  [{'lat': 43.646989, 'label': 'display', 'lng':...  43.646989 -79.393345
# 39  [{'lat': 43.648025841, 'label': 'display', 'ln...  43.648026 -79.379819
# 40  [{'lat': 43.64624476965642, 'label': 'display'...  43.646245 -79.391459
# 41  [{'lat': 43.65564091455335, 'label': 'display'...  43.655641 -79.379199
# 42  [{'lat': 43.646095, 'label': 'display', 'lng':...  43.646095 -79.390144
# 43  [{'lat': 43.651978959035155, 'label': 'display...  43.651979 -79.385049
# 44  [{'lat': 43.647289322295066, 'label': 'display...  43.647289 -79.403493
# 45  [{'lat': 43.664442, 'label': 'display', 'lng':...  43.664442 -79.414456
# 46  [{'lat': 43.65980608863362, 'label': 'display'...  43.659806 -79.395084
# 47  [{'lat': 43.648594, 'label': 'display', 'lng':...  43.648594 -79.392630
# 48  [{'lat': 43.652748, 'label': 'display', 'lng':...  43.652748 -79.399377
# 49  [{'lat': 43.64943515996231, 'label': 'display'...  43.649435 -79.420390
#
#               neighborhood postalCode state                        id
# 0                      NaN    M5V 1J5    ON  4aef8854f964a5201cd921e3
# 1                      NaN        NaN   NaN  5165c333e4b07a7ad88d8a69
# 2                      NaN    M4S 2M6    ON  53a07ba3498ee8946e98a7de
# 3                      NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 4                      NaN    M5G 1C7    ON  4afd920ff964a520ad2822e3
# 5                      NaN        NaN    ON  4b2a634af964a52020a824e3
# 6                      NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 7                      NaN    M5G 1C7    ON  4b2027b5f964a520f82d24e3
# 8                      NaN    M5H 3V1    ON  4fea497c121d2480d3579412
# 9                      NaN    M6P 2G8    ON  4cc5b3babe40a35d7c01864c
# 10                     NaN    M5T 2E3    ON  5c33c7cd8194fc002c66f72e
# 11  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 12                     NaN        NaN    ON  547f94e9498e62f695829624
# 13                     NaN        M5G    ON  4c476d6719fde21e32410876
# 14                     NaN        NaN    ON  4ada6d8df964a520832221e3
# 15                     NaN        NaN    ON  4d06c1ccc2e53704428cc567
# 16                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 17                     NaN    M5H 2L2    ON  50ca02c0245f2d4aa8c2b313
# 18                     NaN    M5G 2N2    ON  596f9dea1fa7632be2eacab9
# 19                     NaN    M5G 1R5    ON  4c69740b8d22c9284d42b745
# 20                     NaN    M5J 1B5    ON  50b79b94e4b0a577af25a83f
# 21                     NaN    M4Y 2G6    ON  4ad4c05ff964a52018f720e3
# 22                     NaN        NaN    ON  4b072e9df964a52009f922e3
# 23                     NaN        NaN    ON  4d137f8c7a8ba1433cb3d169
# 24                     NaN        NaN    ON  4e122e6cb0fbfef99b985de1
# 25                     NaN    M5T 2G6    ON  5b1c3098f96b2c002c5eb0c5
# 26                     NaN    M5T 2G2    ON  4ad4c05ff964a5200bf720e3
# 27                     NaN    M5V 1H3    ON  4ad4c05df964a5203ff620e3
# 28                     NaN    M4W 1A7    ON  4b4d3b51f964a520e4ce26e3
# 29                     NaN    M5T 2Z5    ON  4b82c671f964a52016e430e3
# 30                     NaN    M5H 1Z5    ON  5834c90e110d032f3217f899
# 31                     NaN        M5B    ON  4bd47e6fcfa7b7139f2924da
# 32                     NaN    M5G 2H6    ON  5a8b24b2018cbb6c4ca70dae
# 33                     NaN        NaN    ON  4c12b8ba82a3c9b6083ffaf8
# 34                     NaN    M5J 3A1    ON  562922be498e2c6aad0e6091
# 35                     NaN    M5E 0B7    ON  5c7969857dc9e1002c4e3819
# 36                     NaN        NaN    ON  52a7ae41498eed3af4d0a3fa
# 37      Financial District    M5C 2W1    ON  5c636fa1492814002c0cb117
# 38                     NaN        NaN   NaN  547fcf8d498eea18a9c440c5
# 39                     NaN    M5L 1E2    ON  5b189725d552c7002c0d64c0
# 40                     NaN        NaN    ON  4cb4bf4064998cfaa7f608a2
# 41                     NaN    M5B 1T8    ON  4ad7929cf964a520500c21e3
# 42                     NaN        NaN    ON  59c04747123a197d7984042b
# 43                     NaN    M5H 2N6   NaN  4cffc78a75d3236a3b10e7f7
# 44                     NaN        NaN    ON  4c47d78c1ddec92817ca9e32
# 45                     NaN    M6G 1K7    ON  51e0a7c492093977ebd16779
# 46                     NaN    M5S 3G4    ON  4c7d2f9b10916dcbb99a2896
# 47                     NaN    M5V 1X1    ON  5c0ee730e55d8b002cb81e10
# 48                     NaN    M5T 1H3    ON  59eccc99dff8150ccdd70355
# 49                     NaN    M6J 1X2    ON  4b22e814f964a520175024e3

# %%
dataframe_filtered.describe()
# Out:
#           distance        lat        lng
# count    50.000000  50.000000  50.000000
# mean   1009.320000  43.652627 -79.390431
# std     929.557069   0.006423   0.014168
# min      96.000000  43.639060 -79.459608
# 25%     544.000000  43.648168 -79.393464
# 50%     890.500000  43.652766 -79.386510
# 75%    1086.500000  43.655647 -79.382246
# max    5907.000000  43.670574 -79.374814

# %%
dataframe_cleaned = dataframe_filtered[dataframe_filtered['address'].notnull()]  # get rid records with address "Not available" 
dataframe_TOR=dataframe_cleaned[dataframe_cleaned.state == 'ON']   # get rid of "non ON" states
df_withpostcode=dataframe_TOR[dataframe_TOR['postalCode'].notnull()]  # get rid records with no Postcode
df_withpostcode
# Out:
#                                                  name             categories  \
# 0                        Aroma Fine Indian Restaurant      Indian Restaurant
# 2   Marigold Indian Bistro | Indian Restaurants in...   Fast Food Restaurant
# 3                     Hemispheres Restaurant & Bistro    American Restaurant
# 4                               Indian Biriyani House      Indian Restaurant
# 6                               Victoria's Restaurant             Restaurant
# 7                       Hong Shing Chinese Restaurant     Chinese Restaurant
# 8                               Indian Biriyani House      Indian Restaurant
# 9                  Indian Road Crescent Public School                 School
# 10                      Green Tea Restaurant Downtown             Restaurant
# 11                             Azure Restaurant & Bar             Restaurant
# 13                                    Cali Restaurant  Vietnamese Restaurant
# 16                                     360 Restaurant               Wine Bar
# 17                                  Tundra Restaurant             Restaurant
# 19                         Wah Too Seafood Restaurant     Chinese Restaurant
# 20                                  Indian Roti House      Indian Restaurant
# 21                        Cottage Restaurant & Lounge        Thai Restaurant
# 25            Tasty's Caribbean Restaurant & Catering   Caribbean Restaurant
# 26                    Bright Pearl Seafood Restaurant     Chinese Restaurant
# 27                            Victor Restaurant & Bar                    Bar
# 28                         Matisse Restaurant And Bar             Restaurant
# 29                                  Anoush Restaurant             Restaurant
# 30                             Maezo Restaurant & Bar      Indian Restaurant
# 31                                  Studio Restaurant         Breakfast Spot
# 32                         Hendricks Restaurant & Bar             Restaurant
# 34                                  Evviva Restaurant          Deli / Bodega
# 35                             Chadani Indian Cuisine      Indian Restaurant
# 37                                     Cru Restaurant             Restaurant
# 39                               Ram's Indian kitchen      Indian Restaurant
# 41                             The Senator Restaurant                  Diner
# 45                630 Maroli Indian Kerala Restaurant             Restaurant
# 46                        Veda Healthy Indian Takeout      Indian Restaurant
# 47                              Queen Anne Restaurant     English Restaurant
# 48                          Kim Vietnamese Restaurant  Vietnamese Restaurant
# 49                            The Lakeview Restaurant                  Diner
#
#                             address  cc     city country  \
# 0                    287 King St. W  CA  Toronto  Canada
# 2                   552 Mt Pleasant  CA  Toronto  Canada
# 3               110 Chestnut Street  CA  Toronto  Canada
# 4                   181 Dundas St W  CA  Toronto  Canada
# 6               37 King Street East  CA  Toronto  Canada
# 7                   195 Dundas St W  CA  Toronto  Canada
# 8          120 Adelaide Street West  CA  Toronto  Canada
# 9              285 Indian Road Cres  CA  Toronto  Canada
# 10  261 Spadina Avenue. Upper level  CA  Toronto  Canada
# 11                    225 Frnt St W  CA  Toronto  Canada
# 13                179 Dundas St. W.  CA  Toronto  Canada
# 16                   301 Front St W  CA  Toronto  Canada
# 17         145 Richmond Street West  CA  Toronto  Canada
# 19                   56 Centre Ave.  CA  Toronto  Canada
# 20                256 Queens Quay W  CA  Toronto  Canada
# 21                   338 Jarvis St.  CA  Toronto  Canada
# 25                  405 Spadina Ave  CA  Toronto  Canada
# 26           346-348 Spadina Avenue  CA  Toronto  Canada
# 27                 30 Mercer Street  CA  Toronto  Canada
# 28                     90 Bloor St.  CA  Toronto  Canada
# 29                  250 Dundas St W  CA  Toronto  Canada
# 30          67 Richmond Street West  CA  Toronto  Canada
# 31                   389 Church St.  CA  Toronto  Canada
# 32                  Yonge And Queen  CA  Toronto  Canada
# 34               25 Lower Simcoe St  CA  Toronto  Canada
# 35               51 Colborne Street  CA  Toronto  Canada
# 37                     100 Yonge St  CA  Toronto  Canada
# 39                     199 Bay St 6  CA  Toronto  Canada
# 41              249 Victoria Street  CA  Toronto  Canada
# 45               630 Bloor St. West  CA  Toronto  Canada
# 46             10 Kings College Rd.  CA  Toronto  Canada
# 47             287 Richmond St West  CA  Toronto  Canada
# 48                  546 Dundas St W  CA  Toronto  Canada
# 49                1132 Dundas St. W  CA  Toronto  Canada
#
#                          crossStreet  distance  \
# 0                        at John St.       857
# 2                                NaN      1098
# 3                                NaN       145
# 4                   W of Chestnut St       136
# 6   at Le Meridien King Edward Hotel      1011
# 7                  at University Ave       107
# 8                      at Bay Street       683
# 9                                NaN      5907
# 10                               NaN       845
# 11                               NaN      1039
# 13                       at Chestnut       140
# 16                   301 Front St. W      1271
# 17                    Hilton Toronto       458
# 19                               NaN        96
# 20     btwn Rees St & Lower Simcoe S      1665
# 21           north of Carlton Street      1284
# 25                        College St      1019
# 26                               NaN       960
# 27                        at John St       979
# 28                         Yonge St.      1858
# 29                               NaN       211
# 30           Richmond and Bay Street       537
# 31                    at Carlton St.      1052
# 32                               NaN       607
# 34                 Grand Trunk Cresc      1411
# 35                               NaN      1132
# 37                    Yonge and King       849
# 39                               NaN       889
# 41    btwn Dundas St E and Shuter St       671
# 45                               NaN      2485
# 46               in Sandford Fleming       908
# 47                   Queen and Peter       740
# 48                               NaN       989
# 49                 at Ossington Ave.      2719
#
#                                      formattedAddress  \
# 0   [287 King St. W (at John St.), Toronto ON M5V ...
# 2       [552 Mt Pleasant, Toronto ON M4S 2M6, Canada]
# 3   [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 4   [181 Dundas St W (W of Chestnut St), Toronto O...
# 6   [37 King Street East (at Le Meridien King Edwa...
# 7   [195 Dundas St W (at University Ave), Toronto ...
# 8   [120 Adelaide Street West (at Bay Street), Tor...
# 9   [285 Indian Road Cres, Toronto ON M6P 2G8, Can...
# 10  [261 Spadina Avenue. Upper level, Toronto ON M...
# 11        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 13  [179 Dundas St. W. (at Chestnut), Toronto ON M...
# 16  [301 Front St W (301 Front St. W), Toronto ON ...
# 17  [145 Richmond Street West (Hilton Toronto), To...
# 19       [56 Centre Ave., Toronto ON M5G 1R5, Canada]
# 20  [256 Queens Quay W (btwn Rees St & Lower Simco...
# 21  [338 Jarvis St. (north of Carlton Street), Tor...
# 25  [405 Spadina Ave (College St), Toronto ON M5T ...
# 26  [346-348 Spadina Avenue, Toronto ON M5T 2G2, C...
# 27  [30 Mercer Street (at John St), Toronto ON M5V...
# 28  [90 Bloor St. (Yonge St.), Toronto ON M4W 1A7,...
# 29      [250 Dundas St W, Toronto ON M5T 2Z5, Canada]
# 30  [67 Richmond Street West (Richmond and Bay Str...
# 31  [389 Church St. (at Carlton St.), Toronto ON M...
# 32      [Yonge And Queen, Toronto ON M5G 2H6, Canada]
# 34  [25 Lower Simcoe St (Grand Trunk Cresc), Toron...
# 35   [51 Colborne Street, Toronto ON M5E 0B7, Canada]
# 37  [100 Yonge St (Yonge and King), Toronto ON M5C...
# 39         [199 Bay St 6, Toronto ON M5L 1E2, Canada]
# 41  [249 Victoria Street (btwn Dundas St E and Shu...
# 45   [630 Bloor St. West, Toronto ON M6G 1K7, Canada]
# 46  [10 Kings College Rd. (in Sandford Fleming), T...
# 47  [287 Richmond St West (Queen and Peter), Toron...
# 48      [546 Dundas St W, Toronto ON M5T 1H3, Canada]
# 49  [1132 Dundas St. W (at Ossington Ave.), Toront...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lat': 43.646462521503445, 'label': 'display...  43.646463 -79.389644
# 2   [{'lat': 43.64430171166487, 'label': 'display'...  43.644302 -79.390002
# 3   [{'lat': 43.65488413420439, 'label': 'display'...  43.654884 -79.385931
# 4   [{'lat': 43.65511996683289, 'label': 'display'...  43.655120 -79.386645
# 6   [{'lat': 43.64929834396347, 'label': 'display'...  43.649298 -79.376431
# 7   [{'lat': 43.65492521335936, 'label': 'display'...  43.654925 -79.387089
# 8   [{'lat': 43.650050280518336, 'label': 'display...  43.650050 -79.380662
# 9   [{'lat': 43.66249140470172, 'label': 'display'...  43.662491 -79.459608
# 10  [{'lat': 43.652487830335545, 'label': 'display...  43.652488 -79.397501
# 11  [{'lat': 43.644749195919346, 'label': 'display...  43.644749 -79.385113
# 13  [{'lat': 43.65506808, 'label': 'display', 'lng...  43.655068 -79.386375
# 16  [{'lat': 43.642537317144566, 'label': 'display...  43.642537 -79.387042
# 17  [{'lat': 43.650009987649646, 'label': 'display...  43.650010 -79.385608
# 19  [{'lat': 43.65483285234745, 'label': 'display'...  43.654833 -79.387206
# 20  [{'lat': 43.63906038875002, 'label': 'display'...  43.639060 -79.385422
# 21  [{'lat': 43.66277006654972, 'label': 'display'...  43.662770 -79.376894
# 25  [{'lat': 43.656794, 'label': 'display', 'lng':...  43.656794 -79.399251
# 26  [{'lat': 43.654219, 'label': 'display', 'lng':...  43.654219 -79.399125
# 27  [{'lat': 43.64563436248102, 'label': 'display'...  43.645634 -79.391125
# 28  [{'lat': 43.67057375344845, 'label': 'display'...  43.670574 -79.384856
# 29  [{'lat': 43.654588, 'label': 'display', 'lng':...  43.654588 -79.389692
# 30  [{'lat': 43.651090520885205, 'label': 'display...  43.651091 -79.381843
# 31  [{'lat': 43.661500159065305, 'label': 'display...  43.661500 -79.379319
# 32  [{'lat': 43.65341542752959, 'label': 'display'...  43.653415 -79.379698
# 34  [{'lat': 43.64157991761808, 'label': 'display'...  43.641580 -79.383456
# 35  [{'lat': 43.649153, 'label': 'display', 'lng':...  43.649153 -79.374814
# 37  [{'lat': 43.64982, 'label': 'display', 'lng': ...  43.649820 -79.378350
# 39  [{'lat': 43.648025841, 'label': 'display', 'ln...  43.648026 -79.379819
# 41  [{'lat': 43.65564091455335, 'label': 'display'...  43.655641 -79.379199
# 45  [{'lat': 43.664442, 'label': 'display', 'lng':...  43.664442 -79.414456
# 46  [{'lat': 43.65980608863362, 'label': 'display'...  43.659806 -79.395084
# 47  [{'lat': 43.648594, 'label': 'display', 'lng':...  43.648594 -79.392630
# 48  [{'lat': 43.652748, 'label': 'display', 'lng':...  43.652748 -79.399377
# 49  [{'lat': 43.64943515996231, 'label': 'display'...  43.649435 -79.420390
#
#               neighborhood postalCode state                        id
# 0                      NaN    M5V 1J5    ON  4aef8854f964a5201cd921e3
# 2                      NaN    M4S 2M6    ON  53a07ba3498ee8946e98a7de
# 3                      NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 4                      NaN    M5G 1C7    ON  4afd920ff964a520ad2822e3
# 6                      NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 7                      NaN    M5G 1C7    ON  4b2027b5f964a520f82d24e3
# 8                      NaN    M5H 3V1    ON  4fea497c121d2480d3579412
# 9                      NaN    M6P 2G8    ON  4cc5b3babe40a35d7c01864c
# 10                     NaN    M5T 2E3    ON  5c33c7cd8194fc002c66f72e
# 11  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 13                     NaN        M5G    ON  4c476d6719fde21e32410876
# 16                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 17                     NaN    M5H 2L2    ON  50ca02c0245f2d4aa8c2b313
# 19                     NaN    M5G 1R5    ON  4c69740b8d22c9284d42b745
# 20                     NaN    M5J 1B5    ON  50b79b94e4b0a577af25a83f
# 21                     NaN    M4Y 2G6    ON  4ad4c05ff964a52018f720e3
# 25                     NaN    M5T 2G6    ON  5b1c3098f96b2c002c5eb0c5
# 26                     NaN    M5T 2G2    ON  4ad4c05ff964a5200bf720e3
# 27                     NaN    M5V 1H3    ON  4ad4c05df964a5203ff620e3
# 28                     NaN    M4W 1A7    ON  4b4d3b51f964a520e4ce26e3
# 29                     NaN    M5T 2Z5    ON  4b82c671f964a52016e430e3
# 30                     NaN    M5H 1Z5    ON  5834c90e110d032f3217f899
# 31                     NaN        M5B    ON  4bd47e6fcfa7b7139f2924da
# 32                     NaN    M5G 2H6    ON  5a8b24b2018cbb6c4ca70dae
# 34                     NaN    M5J 3A1    ON  562922be498e2c6aad0e6091
# 35                     NaN    M5E 0B7    ON  5c7969857dc9e1002c4e3819
# 37      Financial District    M5C 2W1    ON  5c636fa1492814002c0cb117
# 39                     NaN    M5L 1E2    ON  5b189725d552c7002c0d64c0
# 41                     NaN    M5B 1T8    ON  4ad7929cf964a520500c21e3
# 45                     NaN    M6G 1K7    ON  51e0a7c492093977ebd16779
# 46                     NaN    M5S 3G4    ON  4c7d2f9b10916dcbb99a2896
# 47                     NaN    M5V 1X1    ON  5c0ee730e55d8b002cb81e10
# 48                     NaN    M5T 1H3    ON  59eccc99dff8150ccdd70355
# 49                     NaN    M6J 1X2    ON  4b22e814f964a520175024e3

# %%
# define the dataframe columns
column_names = ['postalcode', 'Latitude', 'Longitude'] 

# instantiate the dataframe
df_postcode = pd.DataFrame(columns=column_names)
df_postcode
# Out:
# Empty DataFrame
# Columns: [postalcode, Latitude, Longitude]
# Index: []

# %%
#Filling data for each row
df_postcode = df_withpostcode[['postalCode','lat','lng']]
df_postcode.head()
# Out:
#   postalCode        lat        lng
# 0    M5V 1J5  43.646463 -79.389644
# 2    M4S 2M6  43.644302 -79.390002
# 3    M5G 1R3  43.654884 -79.385931
# 4    M5G 1C7  43.655120 -79.386645
# 6    M5C 1E9  43.649298 -79.376431

# %%
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, postalCode in zip(df_postcode['lat'], df_postcode['lng'], df_postcode['postalCode']):
    label = '{}'.format(postalCode)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Filling data for each row
df_postcode = df_withpostcode[['postalCode','lat','lng']]
df_postcode.head()
# Out:
#   postalCode        lat        lng
# 0    M5V 1J5  43.646463 -79.389644
# 2    M4S 2M6  43.644302 -79.390002
# 3    M5G 1R3  43.654884 -79.385931
# 4    M5G 1C7  43.655120 -79.386645
# 6    M5C 1E9  43.649298 -79.376431

# %%
df_postcode['postalCode']=df_postcode['postalCode'].str[:3]
df_postcode.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   postalCode        lat        lng
# 0        M5V  43.646463 -79.389644
# 2        M4S  43.644302 -79.390002
# 3        M5G  43.654884 -79.385931
# 4        M5G  43.655120 -79.386645
# 6        M5C  43.649298 -79.376431

# %%
df_postcode=df_postcode.groupby('postalCode').count() 
df_postcode
# Out:
#             lat  lng
# postalCode
# M4S           1    1
# M4W           1    1
# M4Y           1    1
# M5B           2    2
# M5C           2    2
# M5E           1    1
# M5G           6    6
# M5H           3    3
# M5J           2    2
# M5L           1    1
# M5S           1    1
# M5T           5    5
# M5V           5    5
# M6G           1    1
# M6J           1    1
# M6P           1    1

# %% [markdown]
# Highest count of Indian Restaurants are in M5G (6), M5T (5) and M5V (5)
#
# We can see that postal code starting with M5G is the best place. Second best place for an indian would be M5T and M5V.
# Quick search in wikipedia "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M" indicates that
#
# for M5G Borough is "DownTown Toronto"
# for M5T Borough is "DownTown Toronto"
# for M5V Borough is "DownTown Toronto"
#
# With this we conculde that for any new Indian, it would be best to settle down near "DownTown Toronto" on the basis of the number of Indian Resturants.
